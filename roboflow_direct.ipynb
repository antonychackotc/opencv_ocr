# %%
# !pip install inference-sdk
# Out:
# Collecting inference-sdk
#   Using cached inference_sdk-0.50.4-py3-none-any.whl (43 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.0 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from inference-sdk) (2.32.3)
# Collecting dataclasses-json~=0.6.0
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Collecting opencv-python<=4.10.0.84,>=4.8.1.78
#   Using cached opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
# Requirement already satisfied: pillow<12.0,>=11.0 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from inference-sdk) (11.2.1)
# Collecting supervision<=0.30.0,>=0.25.1
#   Using cached supervision-0.25.1-py3-none-any.whl (181 kB)
# Collecting numpy<2.3.0,>=2.0.0
#   Using cached numpy-2.2.6-cp311-cp311-win_amd64.whl (12.9 MB)
# Collecting aiohttp<=3.10.11,>=3.9.0
#   Using cached aiohttp-3.10.11-cp311-cp311-win_amd64.whl (382 kB)
# Collecting backoff~=2.2.0
#   Using cached backoff-2.2.1-py3-none-any.whl (15 kB)
# Collecting py-cpuinfo~=9.0.0
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Collecting aiohappyeyeballs>=2.3.0
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Collecting attrs>=17.3.0
#   Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.6.2-cp311-cp311-win_amd64.whl (45 kB)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.4.4-cp311-cp311-win_amd64.whl (38 kB)
# Collecting yarl<2.0,>=1.12.0
#   Using cached yarl-1.20.0-cp311-cp311-win_amd64.whl (93 kB)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Using cached marshmallow-3.26.1-py3-none-any.whl (50 kB)
# Collecting typing-inspect<1,>=0.4.0
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from requests<3.0.0,>=2.32.0->inference-sdk) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from requests<3.0.0,>=2.32.0->inference-sdk) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from requests<3.0.0,>=2.32.0->inference-sdk) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from requests<3.0.0,>=2.32.0->inference-sdk) (2025.4.26)
# Requirement already satisfied: contourpy>=1.0.7 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from supervision<=0.30.0,>=0.25.1->inference-sdk) (1.3.2)
# Collecting defusedxml<0.8.0,>=0.7.1
#   Using cached defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Requirement already satisfied: matplotlib>=3.6.0 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from supervision<=0.30.0,>=0.25.1->inference-sdk) (3.10.3)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from supervision<=0.30.0,>=0.25.1->inference-sdk) (6.0.2)
# Collecting scipy<2.0.0,>=1.10.0
#   Using cached scipy-1.15.3-cp311-cp311-win_amd64.whl (41.2 MB)
# Requirement already satisfied: tqdm>=4.62.3 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from supervision<=0.30.0,>=0.25.1->inference-sdk) (4.67.1)
# Requirement already satisfied: packaging>=17.0 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json~=0.6.0->inference-sdk) (25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from matplotlib>=3.6.0->supervision<=0.30.0,>=0.25.1->inference-sdk) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from matplotlib>=3.6.0->supervision<=0.30.0,>=0.25.1->inference-sdk) (4.58.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from matplotlib>=3.6.0->supervision<=0.30.0,>=0.25.1->inference-sdk) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from matplotlib>=3.6.0->supervision<=0.30.0,>=0.25.1->inference-sdk) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from matplotlib>=3.6.0->supervision<=0.30.0,>=0.25.1->inference-sdk) (2.9.0.post0)
# Requirement already satisfied: colorama in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from tqdm>=4.62.3->supervision<=0.30.0,>=0.25.1->inference-sdk) (0.4.6)
# Collecting mypy-extensions>=0.3.0
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json~=0.6.0->inference-sdk) (4.14.0)
# Collecting propcache>=0.2.1
#   Using cached propcache-0.3.1-cp311-cp311-win_amd64.whl (45 kB)
# Requirement already satisfied: six>=1.5 in c:\users\anton\onedrive\desktop\deep-learning-projects\indian_license_plate\indenv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.6.0->supervision<=0.30.0,>=0.25.1->inference-sdk) (1.17.0)
# Installing collected packages: py-cpuinfo, propcache, numpy, mypy-extensions, multidict, marshmallow, frozenlist, defusedxml, backoff, attrs, aiohappyeyeballs, yarl, typing-inspect, scipy, opencv-python, aiosignal, dataclasses-json, aiohttp, supervision, inference-sdk
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.3.0
#     Uninstalling numpy-2.3.0:
#       Successfully uninstalled numpy-2.3.0
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.10.11 aiosignal-1.3.2 attrs-25.3.0 backoff-2.2.1 dataclasses-json-0.6.7 defusedxml-0.7.1 frozenlist-1.6.2 inference-sdk-0.50.4 marshmallow-3.26.1 multidict-6.4.4 mypy-extensions-1.1.0 numpy-2.2.6 opencv-python-4.10.0.84 propcache-0.3.1 py-cpuinfo-9.0.0 scipy-1.15.3 supervision-0.25.1 typing-inspect-0.9.0 yarl-1.20.0
# [notice] A new release of pip available: 22.3 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from inference_sdk import InferenceHTTPClient

client = InferenceHTTPClient(
    api_url="https://serverless.roboflow.com",
    api_key="NTIOU9sAOwsoogTc88UP"
)

result = client.run_workflow(
    workspace_name="licenceplatedetection-i880o",
    workflow_id="custom-workflow",
    images={
        "image": "d3.jpg"
    },
    use_cache=True # cache workflow definition for 15 minutes
)

# %%
result
# Out:
# [{'model_predictions': {'image': {'width': 1024, 'height': 768},
#    'predictions': [{'width': 1010.0,
#      'height': 759.0,
#      'x': 517.0,
#      'y': 379.5,
#      'confidence': 0.7846902012825012,
#      'class_id': 69,
#      'class': 'oven',
#      'detection_id': 'dc07da6d-d132-4911-8abc-e0b8e4ea7fe7',
#      'parent_id': 'image'}]},
#   'label_visualization': '...',
#   'dynamic_crop': [{'crops': '...',
#     'predictions': {'image': {'width': 1024, 'height': 768},
#      'predictions': [{'width': 1010.0,
#        'height': 759.0,
#        'x': 505.0,
#        'y': 379.5,
#        'confidence': 0.7846902012825012,
#        'class_id': 69,
#        'class': 'oven',
#        'detection_id': 'dc07da6d-d132-4911-8abc-e0b8e4ea7fe7',
#        'parent_id': 'image'}]}}],
#   'model_1_predictions': [{'image': {'width': 1010, 'height': 759},
#     'predictions': [{'width': 487.0,
#       'height': 119.0,
#       'x': 501.5,
#       'y': 446.5,
#       'confidence': 0.9504793882369995,
#       'class_id': 0,
#       'class': 'Licence_Plate',
#       'detection_id': '39a119ee-3d47-4782-87ad-b299616e0d32',
#       'parent_id': 'dc07da6d-d132-4911-8abc-e0b8e4ea7fe7'}]}],
#   'dynamic_crop_1': [[{'crops': '...',
#      'predictions': {'image': {'width': 1010, 'height': 759},
#       'predictions': [{'width': 487.0,
#         'height': 119.0,
#         'x': 243.5,
#         'y': 59.5,
#         'confidence': 0.9504793882369995,
#         'class_id': 0,
#         'class': 'Licence_Plate',
#         'detection_id': '39a119ee-3d47-4782-87ad-b299616e0d32',
#         'parent_id': 'dc07da6d-d132-4911-8abc-e0b8e4ea7fe7'}]}}]],
#   'open_ai': [[{'output': 'The license plate reads: MH12DE1433',
#      'classes': None}]],
#   'model_2_predictions': [[{'image': {'width': 487, 'height': 119},
#      'predictions': [{'width': 448.0,
#        'height': 67.0,
#        'x': 263.0,
#        'y': 79.5,
#        'confidence': 0.48174619674682617,
#        'class_id': 0,
#        'class': 'Licence_Plate',
#        'detection_id': 'b2addc21-efa4-45ed-8476-9fc575c44bca',
#        'parent_id': '39a119ee-3d47-4782-87ad-b299616e0d32'}]}]],
#   'stitch_ocr_detections': [['Licence_Plate']],
#   'property_definition': [['LICENCE_PLATE']]}]

# %% [markdown]
# Yolo Manually

# %%
# yolo task=detect mode=train model=yolov8n.pt data=data.yaml epochs=30
